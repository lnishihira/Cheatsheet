# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
adex = pd.read_csv('adex.csv')
adex['fill'] = adex['impressions']/adex['requests']
adex['ecpm'] = (adex['revenue']*1000)/adex['impressions']
adex['blend_ecpm'] = adex['ecpm']*adex['fill']
adex['blend_revenue'] = adex['revenue']*adex['fill']

#pivottable fill rate average
adex_fill = pd.pivot_table(adex,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
adex_fill = adex_fill.reset_index()

#pivotecpm average
adex_ecpm = pd.pivot_table(adex,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
adex_ecpm = adex_ecpm.reset_index()

#pivotBlendedecpm
adex_blendecpm = pd.pivot_table(adex,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
adex_blendecpm = adex_blendecpm.reset_index()

#pivotrevenue
adex_rev = pd.pivot_table(adex,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_rev = adex_rev.reset_index()

#pivotrequests
adex_req = pd.pivot_table(adex,values='requests',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_req = adex_req.reset_index()

#pivot impressions
adex_imp = pd.pivot_table(adex,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_imp = adex_imp.reset_index()

#pivot blended revenue
adex_blend_rev = pd.pivot_table(adex,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
adex_blend_rev = adex_blend_rev.reset_index()

# %%
adex_req = adex_req.reset_index()

# %%
adex_req = pd.pivot_table(adex,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_req = adex_req.reset_index()

# %%
adex_req = adex_req.reset_index()

# %%
adex_req
# Out:
#          index       date_ requests                                      \
# vertical                      autos  culture entertainment gearandstyle
# 0            0  2016-11-01   367563   915967       1133377       885076
# 1            1  2016-11-02   312688  1998319        978244       399602
# 2            2  2016-11-03   221064   706610       1070900       298913
# 3            3  2016-11-04   764729  1234100        932425       596270
# 4            4  2016-11-05   797158   657444        806864       432678
# 5            5  2016-11-06  1294536  1208553        764464       724304
# 6            6  2016-11-07  1034262   764453       1516277       906787
# 7            7  2016-11-08   344680  2726691        708626      2563403
# 8            8  2016-11-09   292501  1666346        866215       337536
# 9            9  2016-11-10   374262  1472918       1265230       229693
# 10          10  2016-11-11   234888   640273        769510      1049557
# ...

# %%
#adex_req = adex_req.drop('ros', axis=1)
adex_req.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_ecpm = adex_ecpm.drop('ros', axis=1)
adex_ecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
#names=['fill','ecpm']
#adex_auto = pd.concat([adex_fill['autos'], adex_ecpm['autos']], axis=1, names=names, ignore_index=True)
adex_auto = pd.concat([adex_fill['autos'], adex_ecpm['autos'], adex_req['autos'],adex_rev['autos'],adex_imp['autos']], axis=1, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f0bea963de38> in <module>()
#       1 #names=['fill','ecpm']
#       2 #adex_auto = pd.concat([adex_fill['autos'], adex_ecpm['autos']], axis=1, names=names, ignore_index=True)
# ----> 3 adex_auto = pd.concat([adex_fill['autos'], adex_ecpm['autos'], adex_req['autos'],adex_rev['autos'],adex_imp['autos']], axis=1, ignore_index=True)
#
# /Users/lilliananishihiraCheatsheet/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
# -> 1995             return self._getitem_multilevel(key)
#    1996         else:
#    1997             return self._getitem_column(key)
#
# /Users/lilliananishihiraCheatsheet/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_multilevel(self, key)
# ...

# %%
adex_auto.columns = adex_auto.columns.astype(str)
adex_auto = adex_auto.rename(index=str, columns={"0":"fill",
                                                 "1":"ecpm",
                                                 "2":"req",
                                                 "3":"rev",
                                                 "4":"imp"})

# %%
#feature_cols = ['fill', 'ecpm','req','rev','imp']
#X = adex_auto[feature_cols]

# %%
#from sklearn.preprocessing import StandardScaler
#stdsc = StandardScaler()
#adex_autoSS = stdsc.fit_transform(adex_auto)

# %%
adex_auto['req'] = adex_auto['req']/10000
adex_auto['rev'] = adex_auto['req']/1000

# %%
adex_pivotbydayblend_rev = adex_pivotbydayblend_rev.drop('ros', axis=1)
adex_pivotbydayblend_rev.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_pivotbydayblendecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_pivotbydayrev = pd.pivot_table(adex,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_pivotbydayrev = adex_pivotbydayrev.reset_index()

# %%
adex_pivotbydayreq = pd.pivot_table(adex,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_pivotbydayreq = adex_pivotbydayreq.reset_index()

# %%
adex_pivotbydayimp = pd.pivot_table(adex,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
adex_pivotbydayimp = adex_pivotbydayimp.reset_index()

# %%
adex_pivotbydayrev.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_pivotbydayreq.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## APPNexus

# %%
appnex = pd.read_csv('appnex.csv')
appnex['fill'] = appnex['impressions']/appnex['requests']
appnex['ecpm'] = (appnex['revenue']*1000)/appnex['impressions']
appnex['blend_ecpm'] = appnex['ecpm']*appnex['fill']
appnex['blend_revenue'] = appnex['revenue']*appnex['fill']

# %%
#pivottable fill rate average
appnex_fill = pd.pivot_table(appnex,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
appnex_fill = appnex_fill.reset_index()

#pivotecpm average
appnex_ecpm = pd.pivot_table(appnex,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
appnex_ecpm = appnex_ecpm.reset_index()

#pivotBlendedecpm
appnex_blendecpm = pd.pivot_table(appnex,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
appnex_blendecpm = appnex_blendecpm.reset_index()

#pivotrevenue
appnex_rev = pd.pivot_table(appnex,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
appnex_rev = appnex_rev.reset_index()

#pivotrequests
appnex_req = pd.pivot_table(appnex,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
appnex_req = appnex_req.reset_index()

#pivot impressions
appnex_imp = pd.pivot_table(appnex,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
appnex_imp = appnex_imp.reset_index()

#pivot blended revenue
appnex_blend_rev = pd.pivot_table(appnex,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
appnex_blend_rev = appnex_blend_rev.reset_index()

# %%
appnex_blend_rev.head(5)

# %%
appnex_blendecpm=appnex_blendecpm.drop('ros',axis=1)
appnex_blendecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
appnex_ecpm=appnex_ecpm.drop('ros',axis=1)
appnex_ecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_ecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
openx_hb_ecpm=openx_hb_ecpm.drop('ros',axis=1)
openx_hb_ecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
openx_hb_ecpm.to_csv('openx_hb_ecpm.csv',index=False)

# %%
triplelift_ecpm=triplelift_ecpm.drop('ros',axis=1)
triplelift_ecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## OpenX

# %%
openx_hb = pd.read_csv('openx_hb.csv')
openx_hb['fill'] = openx_hb['impressions']/openx_hb['requests']
openx_hb['ecpm'] = (openx_hb['revenue']*1000)/openx_hb['impressions']
openx_hb['blend_ecpm'] = openx_hb['ecpm']*openx_hb['fill']
openx_hb['blend_revenue'] = openx_hb['revenue']*openx_hb['fill']

# %%
#pivottable fill rate average
openx_hb_fill = pd.pivot_table(openx_hb,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
openx_hb_fill = openx_hb_fill.reset_index()

#pivotecpm average
openx_hb_ecpm = pd.pivot_table(openx_hb,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
openx_hb_ecpm = openx_hb_ecpm.reset_index()

#pivotBlendedecpm
openx_hb_blendecpm = pd.pivot_table(openx_hb,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
openx_hb_blendecpm = openx_hb_blendecpm.reset_index()

#pivotrevenue
openx_hb_rev = pd.pivot_table(openx_hb,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
openx_hb_rev = openx_hb_rev.reset_index()

#pivotrequests
openx_hb_req = pd.pivot_table(openx_hb,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
openx_hb_req = openx_hb_req.reset_index()

#pivot impressions
openx_hb_imp = pd.pivot_table(openx_hb,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
openx_hb_imp = openx_hb_imp.reset_index()

#pivot blended revenue
openx_hb_blend_rev = pd.pivot_table(openx_hb,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
openx_hb_blend_rev = openx_hb_blend_rev.reset_index()

# %%
openx_hb_blendecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## Triplelift

# %%
triplelift = pd.read_csv('triplelift.csv')
triplelift['fill'] = triplelift['impressions']/triplelift['requests']
triplelift['ecpm'] = (triplelift['revenue']*1000)/triplelift['impressions']
triplelift['blend_ecpm'] = triplelift['ecpm']*triplelift['fill']
triplelift['blend_revenue'] = triplelift['revenue']*triplelift['fill']

# %%
#pivottable fill rate average
triplelift_fill = pd.pivot_table(triplelift,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
triplelift_fill = triplelift_fill.reset_index()

#pivotecpm average
triplelift_ecpm = pd.pivot_table(triplelift,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
triplelift_ecpm = triplelift_ecpm.reset_index()

#pivotBlendedecpm
triplelift_blendecpm = pd.pivot_table(triplelift,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
triplelift_blendecpm = triplelift_blendecpm.reset_index()

#pivotrevenue
triplelift_rev = pd.pivot_table(triplelift,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
triplelift_rev = triplelift_rev.reset_index()

#pivotrequests
triplelift_req = pd.pivot_table(triplelift,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
triplelift_req = triplelift_req.reset_index()

#pivot impressions
triplelift_imp = pd.pivot_table(triplelift,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
triplelift_imp = triplelift_imp.reset_index()

#pivot blended revenue
triplelift_blend_rev = pd.pivot_table(triplelift,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
triplelift_blend_rev = triplelift_blend_rev.reset_index()

# %%
triplelift_ecpm.describe()
# Out:
# vertical      autos    culture  entertainment  gearandstyle  heathandfitness  \
# count     30.000000  30.000000      30.000000     30.000000        30.000000
# mean       3.159214   3.303169       3.131528      3.437088         3.294952
# std        0.319896   0.379572       0.249317      0.415622         0.382353
# min        2.610588   2.642496       2.678051      2.681564         2.415301
# 25%        2.963587   3.074653       2.980970      3.239180         3.177104
# 50%        3.103993   3.227198       3.094865      3.440534         3.306036
# 75%        3.378044   3.463426       3.262019      3.683321         3.462397
# max        3.974062   4.209095       3.712771      4.455304         4.422748
#
# vertical  moneyandcareer        ros     sports
# count          30.000000  30.000000  30.000000
# mean            3.274556   1.200985   3.090910
# std             0.338697   0.138370   0.253823
# min             2.640412   0.978601   2.644590
# ...

# %%
openx_hb_ecpm.describe()
# Out:
# /Users/lilliananishihiraCheatsheet/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# vertical      autos    culture  entertainment  gearandstyle  healthandfitness  \
# count     28.000000  28.000000      28.000000     28.000000         29.000000
# mean       3.240168   3.019957       2.935093      3.195518          2.924481
# std        0.256040   0.335354       0.280916      0.289048          0.598065
# min        2.780987   2.359414       2.480073      2.597776          0.135000
# 25%             NaN        NaN            NaN           NaN               NaN
# 50%             NaN        NaN            NaN           NaN               NaN
# 75%             NaN        NaN            NaN           NaN               NaN
# max        3.688823   3.677461       3.357526      3.674504          3.611682
#
# vertical  moneyandcareer        ros     sports
# ...

# %%
appnex_ecpm.describe()
# Out:
# vertical      autos    culture  entertainment  gearandstyle  healthandfitness  \
# count     30.000000  30.000000      30.000000     30.000000         30.000000
# mean       2.841843   2.850463       2.780740      3.022083          2.911868
# std        0.279711   0.276382       0.261405      0.246141          0.252029
# min        2.273797   2.345447       2.377556      2.515226          2.385809
# 25%        2.691567   2.678881       2.525684      2.867863          2.748163
# 50%        2.852329   2.804007       2.761607      3.052905          2.893912
# 75%        3.032977   3.080354       3.000186      3.180700          3.085501
# max        3.269426   3.288421       3.216637      3.546278          3.303724
#
# vertical  moneyandcareer        ros     sports
# count          30.000000  30.000000  30.000000
# mean            2.909733   2.198011   2.703890
# std             0.236003   0.158309   0.314757
# min             2.374150   1.858362   2.115971
# ...

# %%
triplelift_blendecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## outbrain

# %%
outbrain = pd.read_csv('outbrain.csv')
outbrain.revenue = [x.replace('$', '') for x in outbrain.revenue]
outbrain.revenue = outbrain.revenue.astype(float)

outbrain['fill'] = outbrain['impressions']/outbrain['requests']
outbrain['ecpm'] = (outbrain['revenue']*1000)/outbrain['impressions']
outbrain['blend_ecpm'] = outbrain['ecpm']*outbrain['fill']
outbrain['blend_revenue'] = outbrain['revenue']*outbrain['fill']

# %%
#pivottable fill rate average
outbrain_fill = pd.pivot_table(outbrain,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
outbrain_fill = outbrain_fill.reset_index()

#pivotecpm average
outbrain_ecpm = pd.pivot_table(outbrain,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
outbrain_ecpm = outbrain_ecpm.reset_index()

#pivotBlendedecpm
outbrain_blendecpm = pd.pivot_table(outbrain,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
outbrain_blendecpm = outbrain_blendecpm.reset_index()

#pivotrevenue
outbrain_rev = pd.pivot_table(outbrain,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
outbrain_rev = outbrain_rev.reset_index()

#pivotrequests
outbrain_req = pd.pivot_table(outbrain,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
outbrain_req = outbrain_req.reset_index()

#pivot impressions
outbrain_imp = pd.pivot_table(outbrain,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
outbrain_imp = outbrain_imp.reset_index()

#pivot blended revenue
outbrain_blend_rev = pd.pivot_table(outbrain,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
outbrain_blend_rev = outbrain_blend_rev.reset_index()

# %%
outbrain_blendecpm.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## gumgum

# %%
gum = pd.read_csv('gum.csv')
#gum.revenue = [x.replace('$', '') for x in gum.revenue]
#gum.revenue = gum.revenue.astype(float)

gum['fill'] = gum['impressions']/gum['requests']
gum['ecpm'] = (gum['revenue']*1000)/gum['impressions']
gum['blend_ecpm'] = gum['ecpm']*gum['fill']
gum['blend_revenue'] = gum['revenue']*gum['fill']

# %%
#pivottable fill rate average
gum_fill = pd.pivot_table(gum,values='fill',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
gum_fill = gum_fill.reset_index()

#pivotecpm average
gum_ecpm = pd.pivot_table(gum,values='ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
gum_ecpm = gum_ecpm.reset_index()

#pivotBlendedecpm
gum_blendecpm = pd.pivot_table(gum,values='blend_ecpm',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
gum_blendecpm = gum_blendecpm.reset_index()

#pivotrevenue
gum_rev = pd.pivot_table(appnex,values='revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
gum_rev = gum_rev.reset_index()

#pivotrequests
gum_req = pd.pivot_table(gum,values=['requests'],\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
gum_req = gum_req.reset_index()

#pivot impressions
gum_imp = pd.pivot_table(gum,values='impressions',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='sum')
gum_imp = gum_imp.reset_index()

#pivot blended revenue
gum_blend_rev = pd.pivot_table(gum,values='blend_revenue',\
                                                      index='date_', columns='vertical',\
                                                       aggfunc='mean')
gum_blend_rev = gum_blend_rev.reset_index()

# %%
gum_fill.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
adex_blend_rev.head(1)
adex_blendcpm.head(1)
adex_ecpm.head(1)
adex_fill.head(1)
#adex_imp.head(1)

# %%
    # These are the "Tableau 20" colors as RGB.    
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
                 (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
                 (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
                 (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
                 (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)] 
    # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
        for i in range(len(tableau20)):
            r, g, b = tableau20[i]    
        tableau20[i] = (r / 255., g / 255., b / 255.)   
            
        
    # You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
    # exception because of the number of lines being plotted on it.    
    # Common sizes: (10, 7.5) and (12, 9)    
    plt.figure(figsize=(12, 9))
    
    # Remove the plot frame lines. They are unnecessary chartjunk.    
    ax = plt.subplot(111)    
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False) 
    
    # Ensure that the axis ticks only show up on the bottom and left of the plot.    
    # Ticks on the right and top of the plot are generally unnecessary chartjunk.    
    ax.get_xaxis().tick_bottom()    
    ax.get_yaxis().tick_left()  
    
    # Limit the range of the plot to only where the data is.    
    # Avoid unnecessary whitespace.    
    plt.ylim(0, 6080)   
    
       # Now that the plot is prepared, it's time to actually plot the data!    
    # Note that I plotted the majors in order of the highest % in the final year.    
    vertical = ['ros','heathandfittness','moneyandcareer','entertainment','sports','culture','gearandstyle']
    
     for rank, column in enumerate(vertical):    
        # Plot each line separately with its own color, using the Tableau 20    
        # color set in order.    
        plt.plot(adex_pivotbydayrev.date_.values,    
                adex_pivotbydayrev[column.replace("\n", " ")].values,    
                lw=2.5, color=tableau20[rank])    
      
        # Add a text label to the right end of every line. Most of the code below    
        # is adding specific offsets y position because some labels overlapped.    
        y_pos = adex_pivotbydayreq[column.replace("\n", " ")].values[-1] - 0.5    
        if column == "Foreign Languages":    
            y_pos += 0.5    
        elif column == "English":    
            y_pos -= 0.5    
        elif column == "Communications\nand Journalism":    
            y_pos += 0.75    
        elif column == "Art and Performance":    
            y_pos -= 0.25    
        elif column == "Agriculture":    
            y_pos += 1.25    
        elif column == "Social Sciences and History":    
            y_pos += 0.25    
        elif column == "Business":    
            y_pos -= 0.75    
        elif column == "Math and Statistics":    
            y_pos += 0.75    
        elif column == "Architecture":    
            y_pos -= 0.75    
        elif column == "Computer Science":    
            y_pos += 0.75    
        elif column == "Engineering":    
            y_pos -= 0.25    
      
        # Again, make sure that all labels are large enough to be easily read    
        # by the viewer.    
        plt.text(2011.5, y_pos, column, fontsize=14, color=tableau20[rank])    
      
        plt.show

# %%
plt.adex(x=date_, y=revenue, fmt="r-")
plt.title("Pageessions on example.com")
plt.ylabel("Page impressions")
plt.grid(True)
plt.show()
